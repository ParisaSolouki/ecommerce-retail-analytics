# %% [markdown]
# ## Business Questions
#
# The analysis aims to answer the following business questions:
#
# **Q1. How did sales performance change over time?**
#
# Monthly revenue, order volume, average order value, and year-over-year growth are analyzed to determine the main drivers of sales performance.
#
# ---
#
# **Q2. Which product categories generated the highest sales volume and revenue?**
#
# Product categories are compared by revenue, items sold, order volume, and average item price to identify the strongest-performing categories.
#
# ---
#
# **Q3. Which sellers contributed most to the marketplace, and how did their performance vary?**
#
# Seller revenue, order volume, active-seller count, and revenue concentration are evaluated to understand seller contribution and marketplace performance.
#
# ---
#
# **Q4. How efficiently were orders fulfilled and delivered?**
#
# Fulfillment time, shipping time, total delivery time, on-time delivery rate, and delay duration are analyzed to identify operational strengths and bottlenecks.
#
# ---
#
# **Q5. How satisfied were customers, and how did delivery performance relate to review scores?**
#
# Review scores, positive and negative review rates, delivery status, and product-category performance are analyzed to understand customer satisfaction.
#
# ---
#
# **Q6. Which payment methods were most commonly used by customers?**
#
# Payment-method usage, order share, payment value, and installment behavior are analyzed to understand customer payment preferences.
#
# | Business Question | Key Performance Indicators | Required Tables | Required Columns |
# | --- | --- | --- | --- |
# | Q1. Sales performance over time | Total Revenue, Total Orders, Average Order Value, YoY Growth | orders, payments | order_id, order_purchase_timestamp, payment_value |
# | Q2. Product category performance | Product Revenue, Product Orders, Items Sold, Average Item Price, Revenue Share, Sales Volume Share | orders, order_items, products, category_translation | order_id, product_id, order_item_id, price, product_category_name, product_category_name_english |
# | Q3. Seller performance | Seller Revenue, Seller Orders, Active Sellers, Top 10 Seller Revenue Share | orders, order_items | order_id, seller_id, price, order_purchase_timestamp |
# | Q4. Delivery performance | Average Fulfillment Time, Average Shipping Time, Average Delivery Time, On-Time Delivery Rate, Average Delay Days | orders | order_purchase_timestamp, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date |
# | Q5. Customer satisfaction | Average Review Score, Reviewed Orders, Positive Review Rate, Negative Review Rate, Review Score by Delivery Status | orders, reviews, order_items, products, category_translation | order_id, review_score, order_purchase_timestamp, order_delivered_customer_date, order_estimated_delivery_date, product_id, product_category_name |
# | Q6. Payment-method analysis | Paid Orders, Most Used Payment Method, Payment-Method Share, Total Payment Value, Average Payment Value, Average Installments | orders, payments | order_id, order_purchase_timestamp, payment_type, payment_value, payment_installments |
